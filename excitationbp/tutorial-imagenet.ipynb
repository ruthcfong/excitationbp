# %% [markdown]
# # Excitation Backprop Tutorial: ImageNet Classification
#
# Sam Greydanus. March 2018. MIT License.
#
# In this notebook, we'll use excitation backprop (EB) to explore a VGG-16 model trained on ImageNet.
#
# For an in-depth explanation of EB, refer to [this paper](https://arxiv.org/abs/1608.00507). The [original code](https://github.com/jimmie33/Caffe-ExcitationBP) is in Caffe.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Function, Variable
from torchvision import datasets, models, transforms, utils

import numpy as np
import matplotlib.pyplot as plt

import os, sys, copy ; sys.path.append('..')
import excitationbp as eb

reseed = lambda: np.random.seed(seed=1) ; ms = torch.manual_seed(1) # for reproducibility
reseed()

# %% [markdown]
# ### 1) Load a pretrained model
#
# We'll use the built-in Torch utility.

# %%
# torch has a clean api for loading this model
model = models.vgg16(pretrained=True)
_ = model.train(False) # put model in evaluation mode

# get imagenet class labels from local file
class_labels = []
with open('./data/imagenet/labels.txt', 'r') as f:
    for line in f:
        class_labels.append(line[:-1])
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /Users/ruthfong/.cache/torch/checkpoints/vgg16-397923af.pth
# 100%|██████████| 553433881/553433881 [01:36<00:00, 5743986.16it/s]

# %%
def _resolve_target(target):
    # 'this.that.func' -> this.that, func
    target, attribute = target.rsplit('.', 1)
    components = target.split('.')
    import_path = components.pop(0)
    target = __import__(import_path)
    for comp in components:
        import_path += f".{comp}"
        __import__(import_path)
        target = getattr(target, comp)
    return target, attribute

# %%
class Patch():
    "Patch a callable in a module."

    def __init__(self, target, callable):
        """Patch a callable in a module.

        Args:
            target (str): Path to the callable to patch.
            callable (fun): New callable.
        """
        target, attribute = _resolve_target(target)
        self.target = target
        self.attribute = attribute
        self.orig_callable = getattr(target, attribute)
        setattr(target, attribute, callable)

    def __del__(self):
        self.remove()

    def remove(self):
        "Remove the patch"
        if self.target is not None:
            setattr(self.target, self.attribute, self.orig_callable)
        self.target = None

# %%
class ExcitationBackPropContext(object):

    @staticmethod
    def patch_conv(target_name, enable):
        target, attribute = _resolve_target(target_name)
        conv = getattr(target, attribute)

        def forward(ctx, input, weight, bias=None, *args, **kwargs):
            ctx.save_for_backward(input, weight, bias)
            ctx.args = args
            ctx.kwargs = kwargs
            return conv(input, weight, bias, *ctx.args, **ctx.kwargs)

        def backward(ctx, grad_output):
            # TODO: verify that detach() is required and that there are no
            # unexpected siide effects of this tric
            def get(i):
                x = ctx.saved_tensors[i]
                if x is None:
                    return
                x = x.detach()
                x.requires_grad_(ctx.needs_input_grad[i])
                return x

            inputs_ = get(0), get(1), get(2)
            grad_inputs_ = [None, None, None]
            subset = [i for i, g in enumerate(ctx.needs_input_grad) if g]
            inputs_subset = [inputs_[i] for i in subset]

            with torch.enable_grad():
                # EBP changes only the gradients w.r.t. inputs_[0]. We also compute
                # the gradients w.r.t. the parameters if needed, although they are trash.
                # Perhaps it would be better to set them to None?
                output_ = conv(*inputs_, *ctx.args, **ctx.kwargs)
                _ = torch.autograd.grad(output_, inputs_subset, grad_output, only_inputs=True)
                for i, j in enumerate(subset):
                    grad_inputs_[j] = _[i]

                if ctx.needs_input_grad[0] and enable:
                    output_ebp = conv(
                        inputs_[0], inputs_[1].clamp(min=0), inputs_[2],
                        *ctx.args, **ctx.kwargs
                    )
                    grad_output_norm = grad_output / (output_ebp + 1e-6)
                    grad_inputs_[0] = torch.autograd.grad(
                        output_ebp, inputs_[0], grad_output_norm)[0]
                    grad_inputs_[0] *= inputs_[0]

                return (*grad_inputs_, None, None, None, None, None)

        autograd_conv = type('EBP_' + attribute, (torch.autograd.Function,), {
            'forward': staticmethod(forward),
            'backward': staticmethod(backward),
        })

        return Patch(target_name, autograd_conv.apply)

    def __init__(self, enable=True):
        self.enable = enable

    def __enter__(self):
        self.patches = [
            ExcitationBackPropContext.patch_conv('torch.nn.functional.conv1d', self.enable),
            ExcitationBackPropContext.patch_conv('torch.nn.functional.conv2d', self.enable),
            ExcitationBackPropContext.patch_conv('torch.nn.functional.conv3d', self.enable)
        ]
        return self

    def __exit__(self, type, value, traceback):
        for p in self.patches:
            p.remove()
        return True

# %% [markdown]
# ### 2) Load/classify an example image

# %%
# init a few bookkeeping variables
fig_dir = './figures/'
data_dir = './data/imagenet'

# make the dataloader
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
train_loader = torch.utils.data.DataLoader(
    datasets.ImageFolder(data_dir, transforms.Compose([
        transforms.ToTensor(), normalize,])), batch_size=1)

# load image and classify
data = train_loader.dataset[0][0] # there's just one example image in the data directory. You can add more.

X = Variable(data.resize_(1,3,224,224), requires_grad=True)
y_hat = model(X)
class_id = y_hat.max(1)[1].data.numpy()[0]

# display results
plt.figure(figsize=(4,4))
im = np.mean(data.numpy().reshape(3,224,224), axis=0)
plt.title('prediction: {}'.format(class_labels[class_id][:16]), fontsize=12)
plt.imshow(im, cmap='gray') ; plt.show()

# %% [markdown]
# ### 3) Enter EB Mode
# Refer to **Alg. 1** in the original paper. The relevant (general) equation is:
#
# $$ P_n = A_n \odot W^+ \left(\frac{P_{n-1}}{W^{+T}A_n}\right) $$
#
# We need to do this to the Linear and Conv functions for the model we just trained. Other functions that need this extension include:
#  * average pooling
#  * any pointwise function that has a min value less than 0
#      * these must have their min values subtracted from their outputs

# %%
eb.use_eb(True)
# Out:
# using excitation backprop autograd mode:
# 	->replacing torch.nn.functional.linear with eb_linear...
# 	->replacing torch.nn.functional.conv{1,2,3}d with eb_conv{1,2,3}d...
# 	->replacing torch.nn.functional.avg_pool2d with eb_avg_pool2d...

# %% [markdown]
# ### 4) Excitation Backprop (EB)

# %%
inputs = train_loader.dataset[0][0]
inputs = Variable(inputs.resize_(1,3,224,224))

# compute excitation backprop for correct label
cat_id = 281
dog_id = 219
prob_outputs_cat = Variable(torch.zeros(1,1000)) ; prob_outputs_cat.data[:,cat_id] += 1
prob_outputs_dog = Variable(torch.zeros(1,1000)) ; prob_outputs_dog.data[:,dog_id] += 1

prob_inputs_cat = eb.excitation_backprop(model, inputs, prob_outputs_cat, contrastive=False)
prob_inputs_dog = eb.excitation_backprop(model, inputs, prob_outputs_dog, contrastive=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-5494cf76cdd4> in <module>
#       8 prob_outputs_dog = Variable(torch.zeros(1,1000)) ; prob_outputs_dog.data[:,dog_id] += 1
#       9
# ---> 10 prob_inputs_cat = eb.excitation_backprop(model, inputs, prob_outputs_cat, contrastive=False)
#      11 prob_inputs_dog = eb.excitation_backprop(model, inputs, prob_outputs_dog, contrastive=False)
#
# ~/anaconda3/lib/python3.7/site-packages/excitationbp-0.1-py3.7.egg/excitationbp/utils.py in excitation_backprop(model, inputs, prob_outputs, contrastive, target_layer)
#      37     h3 = layer_target.register_forward_hook(hook_target_h)
#      38
# ---> 39     _ = model(inputs)
#      40     h1.remove() ; h2.remove() ; h3.remove()
#      41     if target_layer == 0:
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     491             result = self._slow_forward(*input, **kwargs)
#     492         else:
# --> 493             result = self.forward(*input, **kwargs)
#     494         for hook in self._forward_hooks.values():
#     495             hook_result = hook(self, input, result)
#
# ~/anaconda3/lib/python3.7/site-packages/torchvision/models/vgg.py in forward(self, x)
#      40
#      41     def forward(self, x):
# ---> 42         x = self.features(x)
#      43         x = self.avgpool(x)
#      44         x = x.view(x.size(0), -1)
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     491             result = self._slow_forward(*input, **kwargs)
#     492         else:
# --> 493             result = self.forward(*input, **kwargs)
#     494         for hook in self._forward_hooks.values():
#     495             hook_result = hook(self, input, result)
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     491             result = self._slow_forward(*input, **kwargs)
#     492         else:
# --> 493             result = self.forward(*input, **kwargs)
#     494         for hook in self._forward_hooks.values():
#     495             hook_result = hook(self, input, result)
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     336                             _pair(0), self.dilation, self.groups)
#     337         return F.conv2d(input, self.weight, self.bias, self.stride,
# --> 338                         self.padding, self.dilation, self.groups)
#     339
#     340
#
# ~/anaconda3/lib/python3.7/site-packages/excitationbp-0.1-py3.7.egg/excitationbp/functions/eb_convNd.py in eb_conv2d(input, weight, bias, stride, padding, dilation, groups)
#     335     if bias is None:
#     336         return f(input, weight)
# --> 337     return f(input, weight, bias)
#     338
#     339 def eb_conv3d(input, weight, bias=None, stride=1, padding=0, dilation=1, groups=1):
#
# ~/anaconda3/lib/python3.7/site-packages/excitationbp-0.1-py3.7.egg/excitationbp/functions/eb_convNd.py in forward(self, input, weight, bias)
#      38         if k == 3:
#      39             input, weight = _view4d(input, weight)
# ---> 40         output = self._update_output(input, weight, bias)
#      41         if k == 3:
#      42             output, = _view3d(output)
#
# ~/anaconda3/lib/python3.7/site-packages/excitationbp-0.1-py3.7.egg/excitationbp/functions/eb_convNd.py in _update_output(self, input, weight, bias)
#     129
#     130         self._bufs = [[] for g in range(self.groups)]
# --> 131         output = self._thnn('update_output', input, weight, bias)
#     132         if not self.requires_grad:
#     133             del self._bufs
#
# ~/anaconda3/lib/python3.7/site-packages/excitationbp-0.1-py3.7.egg/excitationbp/functions/eb_convNd.py in _thnn(self, fn_name, input, weight, *args)
#     191         impl = _thnn_convs[self.thnn_class_name(input)]
#     192         if self.groups == 1:
# --> 193             return impl[fn_name](self, self._bufs[0], input, weight, *args)
#     194         else:
#     195             res = []
#
# ~/anaconda3/lib/python3.7/site-packages/excitationbp-0.1-py3.7.egg/excitationbp/functions/eb_convNd.py in call_update_output(self, bufs, input, weight, bias)
#     263 def make_update_output(fn):
#     264     def call_update_output(self, bufs, input, weight, bias):
# --> 265         backend = type2backend[type(input)]
#     266         bufs.extend([input.new(), input.new()])
#     267         output = input.new(*self._output_size(input, weight))
#
# ~/anaconda3/lib/python3.7/site-packages/torch/_thnn/__init__.py in __getitem__(self, name)
#      13
#      14     def __getitem__(self, name):
# ---> 15         return self.backends[name].load()
#      16
#      17
#
# KeyError: <class 'torch.Tensor'>

# %%
beta = 0.5 # adjust the 'peakiness' of data
cat_img = prob_inputs_cat.clamp(min=0).sum(0).sum(0).data.numpy()
dog_img = prob_inputs_dog.clamp(min=0).sum(0).sum(0).data.numpy()

# visualize
s = 3
f = plt.figure(figsize=[s*3,s])
plt.subplot(1,3,1)
plt.title('Input image')
plt.imshow(inputs.data.sum(0).sum(0).numpy(), cmap='gray')

plt.subplot(1,3,2)
plt.title('EB: "{}"'.format(class_labels[cat_id][:15]))
plt.imshow(cat_img**beta, cmap='gray')

plt.subplot(1,3,3)
plt.title('EB: "{}"'.format(class_labels[dog_id][:15]))
plt.imshow(dog_img**beta, cmap='gray')
plt.show() ; f.savefig('figures/imagenet-eb.png', bbox_inches='tight')

# %% [markdown]
# ### 5) Contrastive Excitation Backprop (c-EB)

# %%
prob_inputs_cat = eb.excitation_backprop(model, inputs, prob_outputs_cat, contrastive=True)
prob_inputs_dog = eb.excitation_backprop(model, inputs, prob_outputs_dog, contrastive=True)

cat_img = prob_inputs_cat.clamp(min=0).sum(0).sum(0).data.numpy()
dog_img = prob_inputs_dog.clamp(min=0).sum(0).sum(0).data.numpy()

# visualize
s = 3
f = plt.figure(figsize=[s*3,s])
plt.subplot(1,3,1)
plt.title('Input image')
plt.imshow(inputs.data.sum(0).sum(0).numpy(), cmap='gray')

plt.subplot(1,3,2)
plt.title('c-EB: "{}"'.format(class_labels[cat_id][:15]))
plt.imshow(cat_img**beta, cmap='gray')

plt.subplot(1,3,3)
plt.title('c-EB: "{}"'.format(class_labels[dog_id][:15]))
plt.imshow(dog_img**beta, cmap='gray')
plt.show() ; f.savefig('figures/imagenet-ceb.png', bbox_inches='tight')

# %% [markdown]
# ### 6) c-EB to a pooling layer

# %%
target_layer = 6
print('Our target layer is: {}'.format( eb.utils.trainable_modules(model)[target_layer] ))

prob_inputs_cat = eb.excitation_backprop(model, inputs, prob_outputs_cat, contrastive=True, target_layer=target_layer)
prob_inputs_dog = eb.excitation_backprop(model, inputs, prob_outputs_dog, contrastive=True, target_layer=target_layer)

cat_img = prob_inputs_cat.clamp(min=0).mean(0).mean(0).data.numpy() # mean over all channels
dog_img = prob_inputs_dog.clamp(min=0).mean(0).mean(0).data.numpy() # mean over all channels

# visualize
s = 3
f = plt.figure(figsize=[s*3,s])
plt.subplot(1,3,1)
plt.title('Input image')
plt.imshow(inputs.data.sum(0).sum(0).numpy(), cmap='gray')

plt.subplot(1,3,2)
plt.title('c-EB (layer {}): "{}"'.format(target_layer, class_labels[cat_id][:10]))
plt.imshow(cat_img**beta, cmap='gray')

plt.subplot(1,3,3)
plt.title('c-EB (layer {}): "{}"'.format(target_layer, class_labels[dog_id][:10]))
plt.imshow(dog_img**beta, cmap='gray')
plt.show() ; f.savefig('figures/imagenet-pool-ceb.png', bbox_inches='tight')
# Out:
# Our target layer is: Conv2d (256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
